# %%
# !python /Users/s2605092/Software/fragment-ranking/src/generate_IFPs.py \
-IFP atomic \
-sdf /Users/s2605092/Data/Fragment-ranking/data/library.sdf \
-exps /Users/s2605092/Data/Fragment-ranking/data/experiments_mArh.json \
-pdbs /Users/s2605092/Data/Fragment-ranking/data/structures/
# Out:
# Total unique compounds in library: 687
# .DS_Store
# .DS_Store error
# [Errno 20] Not a directory: '/Users/s2605092/Data/Fragment-ranking/data/structures/.DS_Store'
# mArh
# mArh-x0423.pdb [10392, 17460, 17462, 19219, 19379]
# mArh-x0436.pdb [13008, 13016]
# mArh-x0631.pdb no interactions detected
# mArh-x0655.pdb [8808, 16800, 16808, 16816, 17003]
# mArh-x0091.pdb [17368, 17376, 19195]
# mArh-x0290.pdb [1140, 1155, 2728, 9216, 9224]
# mArh-x0253.pdb [7555, 9187, 9275, 9528]
# mArh-x0496.pdb [4579, 4604, 14360]
# mArh-x0469.pdb [14144]
# mArh-x0727.pdb [7608, 7619, 9251, 9339, 9368, 9568, 9592]
# mArh-x0524.pdb [7912, 7984, 9632]
# mArh-x0334.pdb [1684, 1688]
# mArh-x0282.pdb [1155, 2840, 9288]
# mArh-x0516.pdb [1684, 1688, 4987]
# mArh-x0259.pdb [6992]
# mArh-x0689.pdb [1140, 1142, 2728, 9288]
# mArh-x0676.pdb [18432, 18454, 18504, 18560, 18576, 20056]
# mArh-x0301.pdb [6371, 6372, 17332, 17580, 17582, 19176, 19272]
# mArh-x0159.pdb [18312, 19856, 19920]
# ...

# %%
# !python /Users/s2605092/Software/fragment-ranking/src/generate_IFPs.py \
-IFP residue \
-sdf /Users/s2605092/Data/Fragment-ranking/data/library.sdf \
-exps /Users/s2605092/Data/Fragment-ranking/data/experiments_mArh.json \
-pdbs /Users/s2605092/Data/Fragment-ranking/data/structures/
# Out:
# Total unique compounds in library: 687
# .DS_Store
# .DS_Store error
# [Errno 20] Not a directory: '/Users/s2605092/Data/Fragment-ranking/data/structures/.DS_Store'
# mArh
# mArh-x0421.pdb [140, 142, 376, 1208, 1209]
# mArh-x0423.pdb [1336, 2268, 2270, 2507, 2523]
# mArh-x0436.pdb [1664]
# mArh-x0142.pdb [140, 376, 400, 403, 1208]
# mArh-x0591.pdb [1011, 1208]
# mArh-x0631.pdb no interactions detected
# mArh-x0592.pdb [140, 1208, 1209]
# mArh-x0587.pdb [142, 376, 1209]
# mArh-x0626.pdb [140, 142, 144, 147, 376, 1208, 1209]
# mArh-x0655.pdb [1152, 2176, 2203]
# mArh-x0091.pdb [2264, 2507]
# mArh-x0681.pdb [144, 348, 1208, 1209]
# mArh-x0722.pdb [142, 147, 152, 352, 376, 1208]
# mArh-x0290.pdb [140, 147, 352, 1208]
# mArh-x0253.pdb [1003, 1211, 1219, 1240]
# mArh-x0496.pdb [619, 620, 1856]
# mArh-x0469.pdb [1824]
# mArh-x0727.pdb [992, 1003, 1211, 1216, 1219, 1240]
# mArh-x0524.pdb [1040, 1048, 1240]
# mArh-x0685.pdb [140, 142, 352, 1208, 1209]
# mArh-x0334.pdb [208, 212]
# ...

# %%
# !python /Users/s2605092/Software/fragment-ranking/src/rank_fragments.py \
-sdf /Users/s2605092/Data/Fragment-ranking/data/library.sdf \
-bits /Users/s2605092/Data/Fragment-ranking/data/smiles_bits_residue.json \
-o ranked_residue.txt
# Out:
# fragments ranked

# %%
# !python /Users/s2605092/Software/fragment-ranking/src/rank_fragments.py \
-sdf /Users/s2605092/Data/Fragment-ranking/data/library.sdf \
-bits /Users/s2605092/Data/Fragment-ranking/data/smiles_bits_atomic.json \
-o ranked_atomic.txt
# Out:
# fragments ranked
